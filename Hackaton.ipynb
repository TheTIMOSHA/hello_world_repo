# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\79671\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\79671\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\79671\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
data = pd.read_csv('./recensions')

# %%
data = data.dropna()

# %%
len(data)
# Out:
# 1994

# %%
#data.to_csv('./recensions', index = False)

# %%
data.head()
# Out:
#   Какая «большая цель» Росатома может вдохновить Вас на работу и наполнить смыслом ваш ежедневный труд?
# 0                    Процветание страны и её народов
# 1  Повышение материального благосостояния страны ...
# 2  Фундаментальные открытия в области энергоресур...
# 3                          Профессиональное развитие
# 4  1. Создание новой технологической платформы/те...

# %%
#!pip install openai

# %%
import openai

# %%
openai.api_key = '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'

# %%
engine="text-davinci-003"

# %%
# prompt = "Назови лучшую Python библиотеку по машинному обучению" 

# # Модель 
# completion = openai.Completion.create(engine=engine, 
#                                       prompt=prompt, 
#                                       temperature=0.5, 
#                                       max_tokens=1000)

# %%
#!python -m spacy download ru_core_news_lg

# %%
import re
import string

import spacy
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem import SnowballStemmer
snowball = SnowballStemmer(language="russian")


porter = PorterStemmer()
wnl = WordNetLemmatizer()
nlp = spacy.load('ru_core_news_lg')
stopwords=nlp.Defaults.stop_words

# %%
stopwords
# Out:
# {'а',
#  'авось',
#  'ага',
#  'агу',
#  'аж',
#  'ай',
#  'али',
#  'алло',
#  'ау',
#  'ах',
#  'ая',
#  'б',
#  'бац',
#  'без',
#  'безусловно',
#  'бишь',
#  'благо',
#  'благодаря',
#  'ближайшие',
#  'близко',
#  'более',
#  'больше',
#  'будем',
#  'будет',
#  'будете',
#  'будешь',
#  'будто',
#  'буду',
#  'будут',
#  'будучи',
#  'будь',
#  'будьте',
#  'бы',
#  'бывает',
#  'бывала',
#  'бывали',
#  'бываю',
#  'бывают',
#  'был',
#  'была',
#  'были',
#  'было',
#  'бытует',
#  'быть',
#  'в',
#  'вам',
#  'вами',
#  'вас',
#  'ваш',
#  'ваша',
#  'ваше',
#  'ваши',
#  'вдали',
#  'вдобавок',
#  'вдруг',
#  'ведь',
#  'везде',
#  'вернее',
#  'весь',
#  'взаимно',
#  'взаправду',
#  'видно',
#  'вишь',
#  'включая',
#  'вместо',
#  'внакладе',
#  'вначале',
#  'вне',
#  'вниз',
#  'внизу',
#  'вновь',
#  'во',
#  'вовсе',
#  'возможно',
#  'воистину',
#  'вокруг',
#  'вон',
#  'вообще',
#  'вопреки',
#  'вот',
#  'вперекор',
#  'вплоть',
#  'вполне',
#  'вправду',
# ...

# %%
def preprocessing(line, snowball= snowball, token=porter, ):
    print(line)
    # Преобразование строки к нижнему регистру и удаление знаков пунктуации
    line = re.sub(r"[{}]".format(string.punctuation), " ", line.lower())
    # Удаление повторяющихся переводов строк и преобразование остальных в пробелы
    line = re.sub(r'«»"\'', '', line)
    line = re.sub(r'«', '', line)
    line = re.sub(r'»', '', line)
    line = re.sub(r"\n\n+", " ", line).replace('\n', ' ')
    line = re.sub(r"\s+", " ", line)
    # Получение списка токенов с помощью spacy
    doc = nlp(line)
    # Список стоп-слов, преобразованный во множество для быстрого поиска
    stop_words_set = set(stopwords)
    # Преобразование каждой леммы токена с помощью стемминга и проверка на наличие в списке стоп-слов
    line = ' '.join([(token.lemma_) for token in doc if token.text not in stop_words_set])
    return line

# %%
new_df = []
for review in data['Какая «большая цель» Росатома может вдохновить Вас на работу и наполнить смыслом ваш ежедневный труд?']:
    review = preprocessing(review)
    new_df.append(review)

# %%
df = pd.DataFrame(new_df, columns=['review'])

# %%
words = []
for w in df['review'][:1999]:
    words.extend(w.split())

# %%
from collections import Counter

# подсчет количества слов в списке
word_count = len(words)
print(f'Количество слов в списке: {word_count}')

# нахождение 15 самых повторяющихся слов
word_counter = Counter(words)
most_common = word_counter.most_common(1000)
print(f'15 самых повторяющихся слов: {most_common}')
# Out:
# Количество слов в списке: 18433
# ...

# %%
most_15_not_stem= [w[0] for w in most_common]

# %%
most_50_not_stem= [w[0] for w in most_common]

# %%
most_500_not_stem= [w[0] for w in most_common]

# %%
most_1000_not_stem= [w[0] for w in most_common]

# %%
most_50_not_stem
# Out:
# ['работа',
#  'цель',
#  'новый',
#  'развитие',
#  'рынок',
#  'росатома',
#  'труд',
#  'международный',
#  'страна',
#  'атомный',
#  'отрасль',
#  'технология',
#  'продукт',
#  'проект',
#  'повышение',
#  'мир',
#  'создание',
#  'сотрудник',
#  'россия',
#  'жизнь',
#  'энергия',
#  'уровень',
#  'мировой',
#  'предприятие',
#  'процесс',
#  'человек',
#  'обеспечение',
#  'больший',
#  'росатом',
#  'смысл',
#  'работать',
#  'аэс',
#  'безопасность',
#  'результат',
#  'работник',
#  'возможность',
#  'улучшение',
#  'разработка',
#  'компания',
#  'ежедневный',
#  'команда',
#  'качество',
#  'лидер',
#  'хороший',
#  'российский',
#  'строительство',
#  'участие',
#  'достижение',
#  'безопасный',
#  'рост']

# %%
most_15_stem
# Out:
# ['цел',
#  'работ',
#  'нов',
#  'развит',
#  'рынок',
#  'росатом',
#  'труд',
#  'международн',
#  'стран',
#  'атомн',
#  'отрасл',
#  'больш',
#  'технолог',
#  'безопасн',
#  'проект']

# %%
tfidf = TfidfVectorizer(
    preprocessor=preprocessing
)

# %%
tfidf_data = (
    tfidf
    .fit_transform(data['rewiew'])
    .toarray().astype('float16')
)

tfidf_data.shape

# %%
d

# %%
words
# Out:
# ['Процветание',
#  'страны',
#  'и',
#  'её',
#  'народов',
#  'Повышение',
#  'материального',
#  'благосостояния',
#  'страны',
#  'и',
#  'моего',
#  'в',
#  'частности',
#  'Фундаментальные',
#  'открытия',
#  'в',
#  'области',
#  'энергоресурсов,',
#  'которые',
#  'позволят',
#  'перевернуть',
#  'общественное',
#  'сознание.',
#  'Профессиональное',
#  'развитие',
#  '1.',
#  'Создание',
#  'новой',
#  'технологической',
#  'платформы/технологического',
#  'уклада',
#  'использования',
#  'атомной',
#  'энергии',
#  'в',
#  'XXI',
#  'в',
#  'Команда,',
#  'которая',
#  'готова',
#  'работать',
#  'сообща',
#  'и',
#  'коллективно',
#  'решать',
#  'сложные',
#  'вопросы.',
#  'Правильное',
#  'разделение',
#  'труда.',
#  'Качество',
#  'продукции',
#  'должно',
#  'быть',
#  'выше',
#  'исполнения',
#  'сроков.',
#  'Качество',
#  'и',
#  'новые',
#  'прогрессивные',
#  'технологии.',
#  '"НИКОГДА',
#  'НЕ',
#  'ОСТАНАВЛИВАЙСЯ',
#  'НА',
#  'ДОСТИГНУТОМ,ИДИ',
#  'ВСЕГДА',
# ...

# %%
#df.to_csv('data_postprocessed_no_steg', index=False)

# %% [markdown]
# # Кластеризация

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
# Загрузка данных из файла CSV
data = pd.read_csv('./data_postprocessed_no_steg')

# %%
data = data.dropna()

# %%
len(data), data
# Out:
# (1983,
#                                                   review
#  0                              процветание страна народ
#  1     повышение материальный благосостояние страна ч...
#  2     фундаментальный открытие область энергоресурсы...
#  3                             профессиональный развитие
#  4     1 создание новый технологический платформа тех...
#  ...                                                 ...
#  1982  повышение качество надёжность продукция являть...
#  1983          становление научный технологический лидер
#  1984     рассказать общество атомный энергия безопасный
#  1985                          новый продукт новый рынок
#  1986  думать цифровизация стратегический приоритет я...
#
#  [1983 rows x 1 columns])

# %%
most_500_not_stem
# Out:
# ['работа',
#  'цель',
#  'новый',
#  'развитие',
#  'рынок',
#  'росатома',
#  'труд',
#  'международный',
#  'страна',
#  'атомный',
#  'отрасль',
#  'технология',
#  'продукт',
#  'проект',
#  'повышение',
#  'мир',
#  'создание',
#  'сотрудник',
#  'россия',
#  'жизнь',
#  'энергия',
#  'уровень',
#  'мировой',
#  'предприятие',
#  'процесс',
#  'человек',
#  'обеспечение',
#  'больший',
#  'росатом',
#  'смысл',
#  'работать',
#  'аэс',
#  'безопасность',
#  'результат',
#  'работник',
#  'возможность',
#  'улучшение',
#  'разработка',
#  'компания',
#  'ежедневный',
#  'команда',
#  'качество',
#  'лидер',
#  'хороший',
#  'российский',
#  'строительство',
#  'участие',
#  'достижение',
#  'безопасный',
#  'рост',
#  'деятельность',
#  'производство',
#  'снижение',
#  'продукция',
#  'ядерный',
#  'задача',
#  'т',
#  'каждый',
#  'большой',
#  'социальный',
#  'энергетика',
#  'направление',
#  'высокий',
#  'единый',
#  'увеличение',
#  'область',
#  'сделать',
# ...

# %%
labels = [0]*len(data['review'])

# %%
for ind, review in enumerate(data['review']):
    for common in most_500_not_stem:
        if common in review:
            labels[ind] = common
            break

# %%
labels.count(0)
# Out:
# 13

# %%
len(data['review'])
# Out:
# 1983

# %%
data['review']
# Out:
# 0                                процветание страна народ
# 1       повышение материальный благосостояние страна ч...
# 2       фундаментальный открытие область энергоресурсы...
# 3                               профессиональный развитие
# 4       1 создание новый технологический платформа тех...
#                               ...
# 1982    повышение качество надёжность продукция являть...
# 1983            становление научный технологический лидер
# 1984       рассказать общество атомный энергия безопасный
# 1985                            новый продукт новый рынок
# 1986    думать цифровизация стратегический приоритет я...
# Name: review, Length: 1983, dtype: object

# %%
labels
# Out:
# ['страна',
#  'страна',
#  'т',
#  'развитие',
#  'новый',
#  'работа',
#  'новый',
#  'т',
#  'работа',
#  'работа',
#  'работа',
#  'процесс',
#  'рынок',
#  'новый',
#  'повышение',
#  'производство',
#  'труд',
#  'рынок',
#  'т',
#  'мир',
#  'труд',
#  'цель',
#  'жизнь',
#  'т',
#  'работа',
#  'росатома',
#  'работа',
#  'работа',
#  'мир',
#  'работа',
#  'атомный',
#  'мир',
#  'новый',
#  'рынок',
#  'лидер',
#  'т',
#  'труд',
#  'снижение',
#  'россия',
#  'рынок',
#  'цель',
#  'цель',
#  'цель',
#  'работа',
#  'проект',
#  'новый',
#  'цифровизация',
#  'развитие',
#  'мир',
#  'обеспечение',
#  'программа',
#  'цель',
#  'работа',
#  'т',
#  'цель',
#  'страна',
#  'рост',
#  'новый',
#  'росатома',
#  'деятельность',
#  'новый',
#  'развитие',
#  'больший',
#  'новый',
#  'рынок',
#  'новый',
#  'работа',
#  'новый',
#  'рынок',
#  'достижение',
#  'атомный',
#  'ядерный',
#  'цель',
#  'работа',
#  'цель',
#  'цель',
#  'рынок',
#  'цель',
#  'работа',
# ...

# %% [markdown]
# # дропаем отзовы в которых не встречается 500 наиболее популярных слов

# %%
for ind, item in enumerate(labels):
    if item == 0:
        print(ind)
        data = data.drop([ind], axis=0)
# Out:
# 315
# 370
# 1108
# 1493
# 1506
# 1614
# 1640
# 1677
# 1737
# 1834
# 1848
# 1941
# 1975

# %%
data['review']
# Out:
# 0                                процветание страна народ
# 1       повышение материальный благосостояние страна ч...
# 2       фундаментальный открытие область энергоресурсы...
# 3                               профессиональный развитие
# 4       1 создание новый технологический платформа тех...
#                               ...
# 1982    повышение качество надёжность продукция являть...
# 1983            становление научный технологический лидер
# 1984       рассказать общество атомный энергия безопасный
# 1985                            новый продукт новый рынок
# 1986    думать цифровизация стратегический приоритет я...
# Name: review, Length: 1970, dtype: object

# %%
while 0 in labels:
    labels.remove(0)

# %%
len(data['review'])
# Out:
# 1970

# %%
len(labels)
# Out:
# 1970

# %%
label_df = pd.DataFrame(labels)

# %%
label_df.head()
# Out:
#           0
# 0    страна
# 1    страна
# 2         т
# 3  развитие
# 4     новый

# %%
data['review'].head()
# Out:
# 0                             процветание страна народ
# 1    повышение материальный благосостояние страна ч...
# 2    фундаментальный открытие область энергоресурсы...
# 3                            профессиональный развитие
# 4    1 создание новый технологический платформа тех...
# Name: review, dtype: object

# %%
vec = [0] * 1576

# %%
# Разделение данных на обучающую и тестовую выборки
#train, test = train_test_split(data, test_size=0.2)
#print(train['review'])
train['review'] = data['review']
X_label = label_df
# Извлечение признаков из текста отзывов
vectorizer = CountVectorizer(stop_words=stopwords)
X_train = vectorizer.fit_transform(train['review'])
X_test = vectorizer.transform(test['review'])
print(X_train.shape)
# Обучение модели на обучающей выборке
clf = MultinomialNB()
clf.fit(X_train, vec)

# # Оценка качества модели на тестовой выборке
# accuracy = clf.score(X_test, test['sentiment'])
# print('Accuracy:', accuracy)

# # Пример использования модели для классификации нового отзыва
# new_review = ['This restaurant has great food and service.']
# X_new = vectorizer.transform(new_review)
# predicted_sentiment = clf.predict(X_new)[0]
# print('Predicted sentiment:', predicted_sentiment)
# Out:
# (1576, 2716)
# MultinomialNB()

# %%
df
# Out:
#                                                  review
# 0                              процветание страна народ
# 1     повышение материальный благосостояние страна ч...
# 2     фундаментальный открытие область энергоресурсы...
# 3                             профессиональный развитие
# 4     1 создание новый технологический платформа тех...
# ...                                                 ...
# 1989  повышение качество надёжность продукция являть...
# 1990          становление научный технологический лидер
# 1991     рассказать общество атомный энергия безопасный
# 1992                          новый продукт новый рынок
# 1993  думать цифровизация стратегический приоритет я...
#
# [1994 rows x 1 columns]
